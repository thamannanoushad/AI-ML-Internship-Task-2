# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('cleaned_titanic.csv')

# %% [markdown]
# ## Understanding the data

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            3         1       3
# 2            4         1       1
# 3            5         0       3
# 4            6         0       3
#
#                                            Name  Sex       Age     SibSp  \
# 0                       Braund, Mr. Owen Harris    1 -0.565736  0.432793
# 1                        Heikkinen, Miss. Laina    0 -0.258337 -0.474545
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  0.433312  0.432793
# 3                      Allen, Mr. William Henry    1  0.433312 -0.474545
# 4                              Moran, Mr. James    1 -0.104637 -0.474545
#
#       Parch            Ticket      Fare  Embarked_C  Embarked_Q  Embarked_S
# 0 -0.473674         A/5 21171 -0.502445       False       False        True
# 1 -0.473674  STON/O2. 3101282 -0.488854       False       False        True
# 2 -0.473674            113803  0.420730       False       False        True
# 3 -0.473674            373450 -0.486337       False       False        True
# 4 -0.473674            330877 -0.478116       False        True       False

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name  Sex  \
# 572          885         0       3        Sutehall, Mr. Henry Jr    1
# 573          887         0       2         Montvila, Rev. Juozas    1
# 574          888         1       1  Graham, Miss. Margaret Edith    0
# 575          890         1       1         Behr, Mr. Karl Howell    1
# 576          891         0       3           Dooley, Mr. Patrick    1
#
#           Age     SibSp     Parch           Ticket      Fare  Embarked_C  \
# 572 -0.335187 -0.474545 -0.473674  SOTON/OQ 392076 -0.506472       False
# 573 -0.181487 -0.474545 -0.473674           211536 -0.386671       False
# 574 -0.796286 -0.474545 -0.473674           112053 -0.044381       False
# 575 -0.258337 -0.474545 -0.473674           111369 -0.044381        True
# 576  0.202762 -0.474545 -0.473674           370376 -0.492378       False
#
#      Embarked_Q  Embarked_S
# 572       False        True
# 573       False        True
# 574       False        True
# 575       False       False
# 576        True       False

# %%
data.shape
# Out:
# (577, 13)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   577.000000  577.000000  577.000000  577.000000  577.000000
# mean    450.590988    0.299827    2.502600    0.752166   -0.004480
# std     259.568357    0.458579    0.733909    0.432129    0.657194
# min       1.000000    0.000000    1.000000    0.000000   -1.872184
# 25%     222.000000    0.000000    2.000000    1.000000   -0.412037
# 50%     455.000000    0.000000    3.000000    1.000000   -0.104637
# 75%     676.000000    1.000000    3.000000    1.000000    0.241187
# max     891.000000    1.000000    3.000000    1.000000    1.893459
#
#             SibSp         Parch        Fare
# count  577.000000  5.770000e+02  577.000000
# mean    -0.293706 -4.736736e-01   -0.347884
# std      0.403796  1.111186e-16    0.253828
# min     -0.474545 -4.736736e-01   -0.648422
# 25%     -0.474545 -4.736736e-01   -0.491874
# 50%     -0.474545 -4.736736e-01   -0.474005
# 75%     -0.474545 -4.736736e-01   -0.329287
# max      1.340132 -4.736736e-01    0.583318

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked_C', 'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %%
data.nunique()
# Out:
# PassengerId    577
# Survived         2
# Pclass           3
# Name           577
# Sex              2
# Age             55
# SibSp            3
# Parch            1
# Ticket         527
# Fare           151
# Embarked_C       2
# Embarked_Q       2
# Embarked_S       2
# dtype: int64

# %%
data['Age'].unique()
# Out:
# array([-0.56573646, -0.25833709,  0.4333115 , -0.1046374 ,  1.89345853,
#        -1.18053521, -0.71943615,  0.12591213,  0.35646166, -1.10368536,
#         0.81756072,  0.97126041, -0.6425863 , -0.87313583, -0.18148724,
#        -0.79628599, -0.02778756, -0.06621248,  0.20276197, -0.33518693,
#         0.04906229, -0.94998568, -0.41203677,  1.27865978,  0.27961182,
#         0.58701119,  0.66386103,  1.35550962, -1.14211029,  0.24118689,
#        -1.33423489,  1.20180994, -0.48888662, -1.02683552,  1.662909  ,
#         1.58605915,  0.51016135,  1.12496009,  1.24023486, -0.68101123,
#        -0.4504617 ,  0.74071088,  1.73975884,  1.43235947,  0.85598564,
#         1.81660868,  1.50920931,  1.04811025, -0.37361185, -1.41108474,
#         0.89441056,  0.08748721, -1.8721838 , -1.25738505,  0.39488658])

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked_C     0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %% [markdown]
# ## histogram for the distribution

# %%
data.hist(figsize=(12,8),bins=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## boxplot for the outliers

# %%
for col in ['Age','Fare','SibSp','Parch']:
    sns.boxplot(x=data[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %% [markdown]
# ## correlation heatmap

# %%
correlation=data.select_dtypes(include='number').corr()

# %%
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(data[['Age','Fare','SibSp','Parch']])

# %% [markdown]
# ## Scatterplot

# %%
plt.figure(figsize=(8,5))
plt.scatter(data['Age'],data['Fare'],c=data['Survived'],cmap='bwr', alpha=0.7)
plt.title('Age vs Fare (Colored by survival)')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.colorbar(label='Survived')
plt.show()
